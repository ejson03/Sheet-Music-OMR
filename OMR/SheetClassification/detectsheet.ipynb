# %%
import numpy as np
import tensorflow as tf
import cv2

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('mobilenetv2.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Lenovo\ML\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Lenovo\ML\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
model.input_shape
# Out:
# (None, 224, 224, 3)

# %%
model.output_shape
# Out:
# (None, 2)

# %%
img = cv2.imread('../images/img1.jpg')

# %%
def show(img):
    cv2.imshow('image', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
show(rimgn[0])

# %%
rimg = cv2.resize(img, (224, 224), interpolation=cv2.INTER_AREA)

# %%
rimg.shape
# Out:
# (224, 224, 3)

# %%
rimgn = np.array([rimg])

# %%
rimgn.shape
# Out:
# (1, 224, 224, 3)

# %%
model.predict(rimgn).flatten()
# Out:
# array([4.7100222e-14, 1.0000000e+00], dtype=float32)

# %%
nimg = cv2.imread('../images/img2.png')

# %%
nimg.shape
# Out:
# (136, 370, 3)

# %%
show(nimg)

# %%
rnimg = cv2.resize(nimg, (224, 224), interpolation=cv2.INTER_AREA)
rnimg = np.array([rnimg])

# %%
model.predict(rnimg).flatten()
# Out:
# array([7.980988e-12, 1.000000e+00], dtype=float32)

# %%
show(rnimg[0])

# %%
show(cv2.putText(img, 'Hello', (100, 100), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 255), 2))
